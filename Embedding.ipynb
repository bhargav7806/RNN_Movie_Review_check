# %%
from tensorflow.keras.preprocessing.text import one_hot
sent = ['the glass is full of milk' , 
         'the glass of juice' , 
         'the cup of tea' , 
         'i am a good boy' , 
         'i am not a bad boy' , 
         'understand the meaning of words' ,
         'your videos are good']

# %%
sent
# Out:
# ['the glass is full of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'i am a good boy',
#  'i am not a bad boy',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## define vacobulary size 
voc_size = 10000

# %%
# one hot representation  
one_hot_repre = [one_hot(word , voc_size) for word in sent]
one_hot_repre
# Out:
# [[1528, 4112, 7974, 1275, 7279, 252],
#  [1528, 4112, 7279, 9067],
#  [1528, 5085, 7279, 6585],
#  [8590, 4299, 3902, 1822, 2664],
#  [8590, 4299, 6931, 3902, 6401, 2664],
#  [3191, 1528, 8316, 7279, 8534],
#  [8756, 3320, 7839, 1822]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences 
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repre , padding = 'pre' , maxlen = sent_length)
embedded_docs
# Out:
# array([[   0,    0, 1528, 4112, 7974, 1275, 7279,  252],
#        [   0,    0,    0,    0, 1528, 4112, 7279, 9067],
#        [   0,    0,    0,    0, 1528, 5085, 7279, 6585],
#        [   0,    0,    0, 8590, 4299, 3902, 1822, 2664],
#        [   0,    0, 8590, 4299, 6931, 3902, 6401, 2664],
#        [   0,    0,    0, 3191, 1528, 8316, 7279, 8534],
#        [   0,    0,    0,    0, 8756, 3320, 7839, 1822]], dtype=int32)

# %%
## feature representation
dim = 10
model = Sequential()
model.add(Embedding(voc_size , dim , input_length = (sent_length,)))
model.compile('adam' , 'mse')

# %%
model.build(input_shape=(None , 8))
print(model.layers)
# Out:
# [<Embedding name=embedding_1, built=True>]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# array([[[-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.02913797, -0.02784003,  0.03768662, -0.03096839,
#          -0.03921147, -0.01862628,  0.00556032,  0.03657612,
#          -0.03460258, -0.00382789],
#         [-0.00329995, -0.02242723, -0.037981  ,  0.00027081,
#           0.0035069 , -0.03154645,  0.03902182, -0.01981077,
#          -0.01290739, -0.00415987],
#         [ 0.04029592, -0.03131559, -0.00954793, -0.01986423,
#           0.01785869, -0.0063898 ,  0.00854597,  0.01683042,
#           0.02006631, -0.02986109],
#         [-0.00998754, -0.00378931, -0.04730253, -0.04531025,
#           0.00779601, -0.02631198, -0.03711724, -0.01341788,
#           0.03830656,  0.01291454],
#         [-0.0173931 ,  0.00943283, -0.00325301,  0.01142732,
#          -0.01517018,  0.03840591, -0.01342685, -0.01167274,
#          -0.04058354, -0.02947382],
#         [-0.04809569,  0.04305227, -0.01159626,  0.00894092,
#           0.03960055, -0.0138476 , -0.03517229,  0.01827917,
#          -0.0092455 , -0.01264795]],
#
#        [[-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.02913797, -0.02784003,  0.03768662, -0.03096839,
#          -0.03921147, -0.01862628,  0.00556032,  0.03657612,
#          -0.03460258, -0.00382789],
#         [-0.00329995, -0.02242723, -0.037981  ,  0.00027081,
#           0.0035069 , -0.03154645,  0.03902182, -0.01981077,
#          -0.01290739, -0.00415987],
#         [-0.0173931 ,  0.00943283, -0.00325301,  0.01142732,
#          -0.01517018,  0.03840591, -0.01342685, -0.01167274,
#          -0.04058354, -0.02947382],
#         [-0.04688623,  0.02191866,  0.04830401,  0.0270214 ,
#          -0.01252728,  0.00561596,  0.00062647,  0.02529483,
#          -0.04299117, -0.03736947]],
#
#        [[-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.02913797, -0.02784003,  0.03768662, -0.03096839,
#          -0.03921147, -0.01862628,  0.00556032,  0.03657612,
#          -0.03460258, -0.00382789],
#         [ 0.01829559, -0.03011423,  0.02003211, -0.00032562,
#           0.00883167,  0.03101895, -0.00441027, -0.01833209,
#           0.02441372,  0.0321109 ],
#         [-0.0173931 ,  0.00943283, -0.00325301,  0.01142732,
#          -0.01517018,  0.03840591, -0.01342685, -0.01167274,
#          -0.04058354, -0.02947382],
#         [-0.01070638,  0.01571914, -0.03786052,  0.04910528,
#           0.0249893 ,  0.031191  , -0.01095705, -0.02410108,
#          -0.00246813,  0.03896468]],
#
#        [[-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.02685026,  0.00593738,  0.02664146,  0.02964355,
#          -0.00313493, -0.00322587,  0.03486754,  0.01698116,
#          -0.01915838,  0.00929817],
#         [ 0.01082746,  0.04671199, -0.04629781, -0.03970949,
#          -0.04284326, -0.0229913 ,  0.01410272,  0.00065111,
#           0.00391847, -0.01578254],
#         [-0.04880565, -0.01237097,  0.04340043,  0.02082062,
#           0.04098621, -0.00150043, -0.03340266,  0.00173486,
#          -0.0085177 ,  0.0021432 ],
#         [-0.03218802,  0.04603967,  0.00212327, -0.01559371,
#           0.00340555,  0.00699327,  0.03493718, -0.02635747,
#           0.04478515, -0.00191693],
#         [ 0.02578104, -0.02894192, -0.03460201,  0.00341339,
#           0.04034945, -0.03060612,  0.04507266, -0.01676688,
#           0.01712979, -0.01962364]],
#
#        [[-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.02685026,  0.00593738,  0.02664146,  0.02964355,
#          -0.00313493, -0.00322587,  0.03486754,  0.01698116,
#          -0.01915838,  0.00929817],
#         [ 0.01082746,  0.04671199, -0.04629781, -0.03970949,
#          -0.04284326, -0.0229913 ,  0.01410272,  0.00065111,
#           0.00391847, -0.01578254],
#         [-0.01882657, -0.03764243,  0.00341327, -0.02834983,
#          -0.03204563,  0.0200429 ,  0.02471578, -0.02811571,
#           0.017508  ,  0.02816821],
#         [-0.04880565, -0.01237097,  0.04340043,  0.02082062,
#           0.04098621, -0.00150043, -0.03340266,  0.00173486,
#          -0.0085177 ,  0.0021432 ],
#         [-0.00337447,  0.03789732, -0.02253094,  0.03954356,
#           0.02923124, -0.04033107,  0.01883825,  0.04557606,
#           0.0402752 , -0.03202911],
#         [ 0.02578104, -0.02894192, -0.03460201,  0.00341339,
#           0.04034945, -0.03060612,  0.04507266, -0.01676688,
#           0.01712979, -0.01962364]],
#
#        [[-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [ 0.02360621,  0.03968206, -0.01935723,  0.0421962 ,
#          -0.03268911, -0.02874833,  0.04992267,  0.00217859,
#           0.03863714, -0.04802069],
#         [-0.02913797, -0.02784003,  0.03768662, -0.03096839,
#          -0.03921147, -0.01862628,  0.00556032,  0.03657612,
#          -0.03460258, -0.00382789],
#         [-0.0264315 ,  0.03087909, -0.01600101,  0.01828984,
#           0.01500422, -0.02469476, -0.03128736, -0.0247754 ,
#          -0.03593981, -0.04749468],
#         [-0.0173931 ,  0.00943283, -0.00325301,  0.01142732,
#          -0.01517018,  0.03840591, -0.01342685, -0.01167274,
#          -0.04058354, -0.02947382],
#         [ 0.00118573,  0.01958612, -0.04006141,  0.0398347 ,
#           0.01372136, -0.02382046,  0.02896254, -0.03775357,
#          -0.02281334,  0.02933511]],
#
#        [[-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04565872,  0.04429959, -0.03286002, -0.02656958,
#          -0.02095049, -0.01649238,  0.03608462, -0.00127469,
#           0.03122571,  0.00181475],
#         [-0.04863195, -0.04954686,  0.0252457 ,  0.02551583,
#          -0.03610601,  0.02446778, -0.04500554, -0.02073344,
#          -0.01147568,  0.04254729],
#         [-0.03769815,  0.04312476,  0.04220251, -0.00374489,
#           0.02827461,  0.01465747, -0.01539702, -0.00957613,
#          -0.0286343 ,  0.04799166],
#         [-0.00695701, -0.04677236,  0.01663414,  0.03854192,
#          -0.02582691, -0.02861829, -0.02006161, -0.02913169,
#           0.00476445,  0.04755813],
#         [-0.03218802,  0.04603967,  0.00212327, -0.01559371,
#           0.00340555,  0.00699327,  0.03493718, -0.02635747,
#           0.04478515, -0.00191693]]], dtype=float32)

# %%
model.predict( )
